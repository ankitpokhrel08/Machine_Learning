# %%
#Read a whole file content
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hello!
# It takes a block of text as input and works out the proportion of characters within the text according to a chosen order.

# %%
#Read a file line by line
with open('example.txt','r') as file:
    for line in file:
        print(line.strip()) ##strip() removes the newline character
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
# dir(line)
# writing a file (over written in file)
with open("example.txt",'w') as file:
    file.write("Hello world\n")
    file.write("Hello world\n")
    file.write("Hello world\n")
    file.write("Hello world\n")
    file.write("Hello world\n")
    file.write("Hello world\n")
    file.write("Hello world\n")

# %%
#appending into previous file without overwriting
with open("example.txt",'a') as file:
    file.write("Nepal")

# %%
import requests
response = requests.get("https://www.google.com")
with open("google.html",'w') as file:
    for line in response.text:
        file.write(line.strip())

# %%
import requests

response = requests.get("https://www.google.com")

# Write HTML content line by line
with open("google.html", 'w', encoding='utf-8') as file:
    for line in response.text.splitlines():
        file.write(line + '\n')

# %%
import requests

# Fetch the HTML content of the webpage
response = requests.get("https://x.com/")

# Save the HTML content to a file
with open("twitter.html", 'w', encoding='utf-8') as file:
    file.write(response.text)

# %%
#writing line in files form list
lines = ['First line\n','Second line\n']
with open("newmethod.txt","w") as file:
    # for line in lines:
    #     file.write(line)
    file.writelines(lines)

# %%
#Writing in binary file
data = b"\x00\x02"
with open("example.bin",'wb') as file:
    file.write(data)
#reading is with "rb"

# %%
### Read the content from a source text file and write to a destination
with open("example.txt","r") as file:
    content = file.read()
with open("destination.md","w") as dest:
    dest.write(content)

# %%
#writing and reading a file
with open("example.txt", "w+") as writeread:
    writeread.write("I am Groot")
    #You have to move the cursor to the beginning and then print the content else it won't work
    writeread.seek(0)
    content = writeread.read()
content
# Out:
# 'I am Groot'

# %%
import os
new_directory = "codepackage"
os.mkdir(new_directory)
print(f"Directory {new_directory} created")
# Out:
# Directory codepackage created

# %%
items= os.listdir('.')
items
# Out:
# ['source_copy.txt',
#  'google.html',
#  'example.csv',
#  'twitter.html',
#  'python_basics.ipynb',
#  'codepackage',
#  'source.txt',
#  'destination.md',
#  'example.bin',
#  'example.txt',
#  'importing.ipynb',
#  '.ipynb_checkpoints',
#  'file_operation.ipynb',
#  'newmethod.txt',
#  'package',
#  'new.txt']

# %%
#Important
### Joining Paths

dir_name = "newfolder"
file_name = "newfile.txt"
full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# newfolder/newfile.txt

# %%
#Get all the files 
dir_name = "newfolder"
file_name = "newfile.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# /Users/ankitpokhrel/Documents/Machine-Learning/Course/python_recap/python_basis/newfolder/newfile.txt

# %%
path = 'example2.txt'
if os.path.exists(path):
    print(f'The path {path} exists')
    with open("example2.txt",'r') as examp:
        print(examp.read())

else:
   with open("example2.txt","w") as exp:
       exp.write("Hello World")
# Out:
# The path example2.txt exists
# Hello World

# %%
#check file or directory
import os
path = "example.txt"
os.path.isfile(path)
os.path.isdir(path)
# Out:
# False

# %%
#getting the absoulte path(You can also do upper mentioned code)
import os
relative_path = "example.txt"
absolute_path =  os.path.abspath(relative_path)
absolute_path
# Out:
# '/Users/ankitpokhrel/Documents/Machine-Learning/Course/python_recap/python_basis/example.txt'

# %%
import os
import random
import numpy
import pandas
