# %%
import numpy as np
import pandas as pd

# %%
import datetime

# %%
test1 = datetime.datetime(22,12,10)

# %%
test = pd.Timestamp("2022-12-10")

# %%
test.day_name()
# Out:
# 'Saturday'

# %%
pd.DatetimeIndex(['2022-12-10','2022-12-11','2022-12-12'])
# Out:
# DatetimeIndex(['2022-12-10', '2022-12-11', '2022-12-12'], dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start='2022-12-11' , end = '2023-01-07' , freq='D')
# Out:
# DatetimeIndex(['2022-12-11', '2022-12-12', '2022-12-13', '2022-12-14',
#                '2022-12-15', '2022-12-16', '2022-12-17', '2022-12-18',
#                '2022-12-19', '2022-12-20', '2022-12-21', '2022-12-22',
#                '2022-12-23', '2022-12-24', '2022-12-25', '2022-12-26',
#                '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30',
#                '2022-12-31', '2023-01-01', '2023-01-02', '2023-01-03',
#                '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, 454 to 448
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    datetime64[ns]
#  1   delivery_date  501 non-null    datetime64[ns]
#  2   days_gap       501 non-null    timedelta64[ns]
# dtypes: datetime64[ns](2), timedelta64[ns](1)
# memory usage: 15.7 KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Downloads/All projects/ML Projects/campusx/env/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[187], line 1
# ...

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2004-08-19    49.813290    51.835709    47.800831    49.982655
# 1    2004-08-20    50.316402    54.336334    50.062355    53.952770
# 2    2004-08-23    55.168217    56.528118    54.321388    54.495735
# 3    2004-08-24    55.412300    55.591629    51.591621    52.239197
# 4    2004-08-25    52.284027    53.798351    51.746044    52.802086
# ...         ...          ...          ...          ...          ...
# 4466 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close    Volume
# 0       49.982655  44871361
# 1       53.952770  22942874
# 2       54.495735  18342897
# 3       52.239197  15319808
# ...

# %%
df['Date'].dt.month_name()
# Out:
# 0       August
# 1       August
# 2       August
# 3       August
# 4       August
#          ...
# 4466       May
# 4467       May
# 4468       May
# 4469       May
# 4470       May
# Name: Date, Length: 4471, dtype: object

# %%
#Time delta
d1 = pd.Timestamp('12th Jan 2022')
d2 = pd.Timestamp('15th Jan 2022')
d2-d1
# Out:
# Timedelta('3 days 00:00:00')

# %%
pd.Timedelta(days=20,hours = 20,minutes=22)
# Out:
# Timedelta('20 days 20:22:00')

# %%
pd.date_range(start='20th Jun 2022' ,end = '16th Jul 2022' , freq = 'D') - pd.Timedelta(days=20,hours = 20,minutes=22)
# Out:
# DatetimeIndex(['2022-05-30 03:38:00', '2022-05-31 03:38:00',
#                '2022-06-01 03:38:00', '2022-06-02 03:38:00',
#                '2022-06-03 03:38:00', '2022-06-04 03:38:00',
#                '2022-06-05 03:38:00', '2022-06-06 03:38:00',
#                '2022-06-07 03:38:00', '2022-06-08 03:38:00',
#                '2022-06-09 03:38:00', '2022-06-10 03:38:00',
#                '2022-06-11 03:38:00', '2022-06-12 03:38:00',
#                '2022-06-13 03:38:00', '2022-06-14 03:38:00',
#                '2022-06-15 03:38:00', '2022-06-16 03:38:00',
#                '2022-06-17 03:38:00', '2022-06-18 03:38:00',
#                '2022-06-19 03:38:00', '2022-06-20 03:38:00',
#                '2022-06-21 03:38:00', '2022-06-22 03:38:00',
#                '2022-06-23 03:38:00', '2022-06-24 03:38:00',
#                '2022-06-25 03:38:00'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.read_csv("data/deliveries.csv")

# %%
df.head()
# Out:
#   order_date delivery_date
# 0    5/24/98        2/5/99
# 1    4/22/92        3/6/98
# 2    2/10/91       8/26/92
# 3    7/21/92      11/20/97
# 4     9/2/93       6/10/98

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['delivery_date'] = pd.to_datetime(df['delivery_date'])
# Out:
# /var/folders/4j/n0rl6b3s0657t_7z21qxxz6w0000gn/T/ipykernel_79958/3472121163.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['order_date'] = pd.to_datetime(df['order_date'])
# /var/folders/4j/n0rl6b3s0657t_7z21qxxz6w0000gn/T/ipykernel_79958/3472121163.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['delivery_date'] = pd.to_datetime(df['delivery_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    datetime64[ns]
#  1   delivery_date  501 non-null    datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 8.0 KB

# %%
df['days_gap'] =  df['delivery_date'] - df['order_date']

# %%
df.head()
# Out:
#   order_date delivery_date  days_gap
# 0 1998-05-24    1999-02-05  257 days
# 1 1992-04-22    1998-03-06 2144 days
# 2 1991-02-10    1992-08-26  563 days
# 3 1992-07-21    1997-11-20 1948 days
# 4 1993-09-02    1998-06-10 1742 days

# %%
df.sort_values('days_gap' , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, 454 to 448
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    datetime64[ns]
#  1   delivery_date  501 non-null    datetime64[ns]
#  2   days_gap       501 non-null    timedelta64[ns]
# dtypes: datetime64[ns](2), timedelta64[ns](1)
# memory usage: 15.7 KB

# %%
df['days_gap'].min()
# Out:
# Timedelta('8 days 00:00:00')

# %%
df.sample(10)
# Out:
#     order_date delivery_date  days_gap
# 365 1992-12-01    1994-10-29  697 days
# 486 1994-10-01    1999-07-25 1758 days
# 317 1993-05-24    1998-09-20 1945 days
# 66  1997-04-02    1997-08-28  148 days
# 259 1996-04-14    1998-02-28  685 days
# 415 1990-04-16    1998-05-18 2954 days
# 175 1991-06-11    1999-06-24 2935 days
# 411 1994-01-27    1997-10-31 1373 days
# 128 1991-08-01    1996-09-26 1883 days
# 414 1991-12-12    1999-09-15 2834 days

# %%
google = pd.read_csv("data/google.csv")

# %%
google.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
google['Date'] = pd.to_datetime(google['Date'])

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   datetime64[ns]
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 244.6 KB

# %%
google.set_index("Date", inplace=True)

# %%
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
google.loc['2007-12']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2007-12-03  344.214813  346.202362  339.298218  339.492493  339.492493
# 2007-12-04  337.888519  344.707947  337.295746  340.802582  340.802582
# 2007-12-05  345.071594  348.160004  342.466339  347.950806  347.950806
# 2007-12-06  347.597107  356.942108  347.203583  356.294525  356.294525
# 2007-12-07  356.160034  357.659393  353.923401  356.100250  356.100250
# 2007-12-10  356.658173  361.046722  355.666870  357.868622  357.868622
# 2007-12-11  358.625793  359.148834  348.085297  348.294495  348.294495
# 2007-12-12  355.666870  355.826263  342.964478  348.369232  348.369232
# 2007-12-13  346.854889  347.507446  339.333099  345.729126  345.729126
# 2007-12-14  342.471344  348.543579  342.346802  343.691772  343.691772
# 2007-12-17  342.715424  346.411560  330.595856  333.365479  333.365479
# 2007-12-18  335.821259  337.091492  325.031708  335.417786  335.417786
# ...

# %%
google['Open']
# Out:
# Date
# 2004-08-19      49.813290
# 2004-08-20      50.316402
# 2004-08-23      55.168217
# 2004-08-24      55.412300
# 2004-08-25      52.284027
#                  ...
# 2022-05-16    2307.679932
# 2022-05-17    2344.550049
# 2022-05-18    2304.750000
# 2022-05-19    2236.820068
# 2022-05-20    2241.709961
# Name: Open, Length: 4471, dtype: float64

# %%
google['month_name'] = google.index.month_name()

# %%
google['day_name'] = google.index.day_name()

# %%
google.day_name
# Out:
# Date
# 2004-08-19     Thursday
# 2004-08-20       Friday
# 2004-08-23       Monday
# 2004-08-24      Tuesday
# 2004-08-25    Wednesday
#                 ...
# 2022-05-16       Monday
# 2022-05-17      Tuesday
# 2022-05-18    Wednesday
# 2022-05-19     Thursday
# 2022-05-20       Friday
# Name: day_name, Length: 4471, dtype: object

# %%
google.groupby('month_name')['High'].mean().sort_values(ascending=False)
# Out:
# month_name
# February     745.953527
# March        743.921782
# April        743.225185
# January      733.280160
# December     731.910811
# November     723.433358
# May          713.134478
# July         695.993643
# August       691.275014
# October      689.504402
# September    679.271536
# June         664.978331
# Name: High, dtype: float64

# %%
google.groupby('month_name')['Close'].max().sort_values(ascending=False)
# Out:
# month_name
# November     3014.179932
# December     2974.409912
# October      2965.409912
# February     2960.729980
# September    2916.840088
# August       2909.389893
# January      2901.489990
# April        2872.850098
# March        2865.000000
# July         2792.889893
# June         2545.639893
# May          2451.500000
# Name: Close, dtype: float64

# %%
google.Close
# Out:
# Date
# 2004-08-19      49.982655
# 2004-08-20      53.952770
# 2004-08-23      54.495735
# 2004-08-24      52.239197
# 2004-08-25      52.802086
#                  ...
# 2022-05-16    2295.850098
# 2022-05-17    2334.030029
# 2022-05-18    2248.020020
# 2022-05-19    2214.909912
# 2022-05-20    2186.260010
# Name: Close, Length: 4471, dtype: float64

# %%
google.iloc[0:10]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276
# 2004-08-26  52.279045  53.773445  52.134586  53.753517  53.753517   7128620
# 2004-08-27  53.848164  54.107193  52.647663  52.876804  52.876804   6241307
# 2004-08-30  52.443428  52.548038  50.814533  50.814533  50.814533   5221498
# 2004-08-31  50.958992  51.661362  50.889256  50.993862  50.993862   4941252
# 2004-09-01  51.158245  51.292744  49.648903  49.937820  49.937820   9181687
#
#            month_name   day_name
# Date
# 2004-08-19     August   Thursday
# 2004-08-20     August     Friday
# ...

# %%
google.head(10)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276
# 2004-08-26  52.279045  53.773445  52.134586  53.753517  53.753517   7128620
# 2004-08-27  53.848164  54.107193  52.647663  52.876804  52.876804   6241307
# 2004-08-30  52.443428  52.548038  50.814533  50.814533  50.814533   5221498
# 2004-08-31  50.958992  51.661362  50.889256  50.993862  50.993862   4941252
# 2004-09-01  51.158245  51.292744  49.648903  49.937820  49.937820   9181687
#
#            month_name   day_name
# Date
# 2004-08-19     August   Thursday
# 2004-08-20     August     Friday
# ...

# %%
google.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
#              Volume month_name   day_name
# Date
# 2022-05-16  1164100        May     Monday
# 2022-05-17  1078800        May    Tuesday
# 2022-05-18  1399100        May  Wednesday
# 2022-05-19  1459600        May   Thursday
# 2022-05-20  1878100        May     Friday

# %%
google.groupby('month_name')['Close'].max().plot(kind = 'bar')
# Out:
# <Axes: xlabel='month_name'>

# %%
google.groupby('day_name')['Volume'].max().plot(kind = 'bar')
# Out:
# <Axes: xlabel='day_name'>

# %%
google.groupby('month_name')['Volume'].max().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='month_name'>

# %%
google.index.day
# Out:
# Index([19, 20, 23, 24, 25, 26, 27, 30, 31,  1,
#        ...
#         9, 10, 11, 12, 13, 16, 17, 18, 19, 20],
#       dtype='int32', name='Date', length=4471)

# %%
google['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google.loc['2022']['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google.loc['2021':'2022']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google.loc['2020-10' : '2021-01']['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# google['Volume'].plot()
google['Volume'].resample('M').mean().plot()
google['Volume'].resample('Q').mean().plot()
# Out:
# /var/folders/4j/n0rl6b3s0657t_7z21qxxz6w0000gn/T/ipykernel_79958/3782106070.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   google['Volume'].resample('M').mean().plot()
# /var/folders/4j/n0rl6b3s0657t_7z21qxxz6w0000gn/T/ipykernel_79958/3782106070.py:3: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   google['Volume'].resample('Q').mean().plot()
# <Axes: xlabel='Date'>

# %%
# google['Close'].rolling(3).mean().plot()
google['Close'].rolling(500).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Close'].rolling(3).mean().plot()
google['Close'].ewm(15).mean().plot()
# Out:
# <Axes: xlabel='Date'>
