# %%
import pandas as pd
import numpy as np

# %%
#Timestamp
current = pd.Timestamp("2022, 01, 16")
type(current)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
import time

# %%
start = time.time()
pd.Timestamp(start)
# Out:
# Timestamp('1970-01-01 00:00:01.748412574')

# %%
pd.Timestamp("2022-01-16-12-13AM")
# Out:
# Timestamp('2022-01-16 00:00:00-1300', tz='tzoffset(None, -46800)')

# %%
import datetime as dt

# %%
x =pd.Timestamp(dt.datetime(2022,12,20,1,30))

# %%
x.minute
# Out:
# 30

# %%
#Datetime Index --> Collection of Timestamp
a = pd.DatetimeIndex(['2022-2-20','2022/12/13'])

# %%
a
# Out:
# DatetimeIndex(['2022-02-20', '2022-12-13'], dtype='datetime64[ns]', freq=None)

# %%
a
# Out:
# DatetimeIndex(['2022-02-20', '2022-12-13'], dtype='datetime64[ns]', freq=None)

# %%
pd.Series([1,2],a).reset_index().rename(columns={'index' : 'date'})
# Out:
#         date  0
# 0 2022-02-20  1
# 1 2022-12-13  2

# %%
pd.date_range(start = '2025/05/20' , end = '6/05/30', freq='W')
# Out:
# DatetimeIndex(['2025-05-25', '2025-06-01', '2025-06-08', '2025-06-15',
#                '2025-06-22', '2025-06-29', '2025-07-06', '2025-07-13',
#                '2025-07-20', '2025-07-27',
#                ...
#                '2030-03-31', '2030-04-07', '2030-04-14', '2030-04-21',
#                '2030-04-28', '2030-05-05', '2030-05-12', '2030-05-19',
#                '2030-05-26', '2030-06-02'],
#               dtype='datetime64[ns]', length=263, freq='W-SUN')

# %%
df = pd.read_csv("data/expense_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df['Day'] = pd.to_datetime(df['Date']).dt.day

# %%
df
# Out:
#                    Date               Account        Category  Subcategory  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1   2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2   2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4   2022-03-01 18:22:00  CUB - online payment            Food          NaN
# ..                  ...                   ...             ...          ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 273 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation          NaN
# 275 2021-11-21 15:50:00  CUB - online payment            Food          NaN
# 276 2021-11-21 13:30:00  CUB - online payment           Other          NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
#  11  Day             277 non-null    object
#  12  Month           277 non-null    object
#  13  year            277 non-null    int32
# dtypes: datetime64[ns](1), float64(5), int32(1), object(7)
# memory usage: 29.3+ KB

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['day_name'], df['INR'])

# %%
df.groupby('Month')['INR'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Month'>

# %%
df.groupby('day_name')['INR'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='day_name'>
