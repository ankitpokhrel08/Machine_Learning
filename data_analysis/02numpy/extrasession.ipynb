# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#plotting 3D graph and meshgrid
x = np.linspace(-10,10,10)
y = np.linspace(-10,10,10)
xx,yy = np.meshgrid(x,y)

# %%
plt.scatter(xx,yy)

# %%
def func(x, y):
    return np.cos(x**2) + np.sin(y**2)
zz = func(xx, yy)

# %%
import plotly.express as px
import plotly.graph_objects as go

fig = px.scatter_3d()
fig.add_trace(go.Surface(x=xx,y=yy,z=zz))
fig.show()

# %%
np.random.seed(0)
np.random.randint(10,100,20).reshape(4,5)
# Out:
# array([[54, 57, 74, 77, 77],
#        [19, 93, 31, 46, 97],
#        [80, 98, 98, 22, 68],
#        [75, 49, 97, 56, 98]])

# %%
import cv2

# %%
img = cv2.imread('image.png')

# %%
img
# Out:
# array([[[146, 201, 217],
#         [146, 200, 216],
#         [146, 201, 215],
#         ...,
#         [ 90,  73,  59],
#         [ 88,  72,  59],
#         [ 88,  71,  57]],
#
#        [[146, 201, 216],
#         [146, 201, 216],
#         [145, 200, 215],
#         ...,
#         [ 86,  70,  55],
#         [ 85,  69,  55],
#         [ 86,  69,  55]],
#
#        [[146, 201, 216],
#         [146, 201, 216],
#         [145, 201, 215],
#         ...,
#         [ 88,  71,  57],
#         [ 86,  70,  55],
#         [ 87,  70,  55]],
#
#        ...,
#
#        [[ 14,  14,  14],
#         [ 14,  14,  14],
#         [ 14,  14,  14],
#         ...,
#         [ 14,  14,  14],
#         [ 14,  14,  14],
#         [ 14,  14,  14]],
#
#        [[ 14,  14,  14],
#         [ 14,  14,  14],
#         [ 14,  14,  14],
#         ...,
#         [ 14,  14,  14],
#         [ 14,  14,  14],
#         [ 14,  14,  14]],
#
#        [[ 14,  14,  14],
#         [ 14,  14,  14],
#         [ 14,  14,  14],
# ...

# %%
img.shape
# Out:
# (1110, 854, 3)

# %%
plt.imshow(img)

# %%
a = np.random.randint(0,256,6220800).reshape(1080,1920,3)

# %%
plt.imshow(a)

# %%
#negative
plt.imshow(255-img)

# %%
plt.imshow(img[100:200,200:300,:])

# %%
plt.hist(img.ravel(),bins = 255)
# Out:
# (array([ 1725.,  4219.,  6145.,  7929.,  8711.,  8818.,  8489.,  8270.,
#          8308.,  8191.,  8563.,  9397., 10186., 10615., 41587., 10842.,
#         11081., 11235., 11792., 12521., 12847., 13271., 14219., 15426.,
#         16068., 17356., 18042., 18965., 19322., 19531., 19597., 19664.,
#         19491., 19761., 20193., 20034., 20240., 20067., 20170., 20189.,
#         20911., 21268., 21680., 22058., 21704., 21273., 20878., 20237.,
#         20146., 20291., 20456., 20595., 20616., 20349., 19728., 20021.,
#         19622., 20004., 20007., 19869., 19626., 19113., 19138., 18896.,
#         18856., 19096., 19471., 19420., 19418., 19635., 19539., 20022.,
#         19651., 19866., 20498., 20370., 20061., 19664., 19780., 19387.,
#         18973., 19121., 19030., 19148., 19024., 18664., 18465., 18332.,
#         18143., 17961., 17828., 17720., 17736., 17543., 17209., 16906.,
#         16533., 16444., 16210., 15855., 15496., 15392., 15044., 15251.,
# ...

# %%
white = cv2.imread('white.png')
plt.hist(white.flatten(),bins = 255)
# Out:
# (array([6.200000e+02, 9.600000e+01, 9.500000e+01, 9.800000e+01,
#         1.380000e+02, 1.210000e+02, 1.060000e+02, 1.420000e+02,
#         1.210000e+02, 1.240000e+02, 1.110000e+02, 1.370000e+02,
#         1.250000e+02, 1.440000e+02, 1.350000e+02, 1.370000e+02,
#         1.520000e+02, 1.720000e+02, 1.460000e+02, 1.770000e+02,
#         3.410000e+02, 3.240000e+02, 3.950000e+02, 1.233000e+03,
#         1.561000e+03, 1.360200e+04, 2.538000e+03, 2.995000e+03,
#         1.954000e+03, 1.608000e+03, 1.832000e+03, 2.369000e+03,
#         2.113000e+03, 2.282000e+03, 2.679000e+03, 3.166000e+03,
#         2.454000e+03, 2.446000e+03, 2.199000e+03, 1.986000e+03,
#         1.701000e+03, 1.573000e+03, 1.812000e+03, 1.349000e+03,
#         1.437000e+03, 1.405000e+03, 1.387000e+03, 1.456000e+03,
#         1.327000e+03, 1.323000e+03, 1.213000e+03, 1.327000e+03,
#         1.201000e+03, 1.160000e+03, 1.278000e+03, 1.448000e+03,
#         1.228000e+03, 1.174000e+03, 1.231000e+03, 1.201000e+03,
# ...
