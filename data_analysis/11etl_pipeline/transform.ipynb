# %%
import pandas as pd
import numpy as np
import seaborn as sbs

# %%
ipl = pd.read_csv("ball_by_ball_ipl.csv")

# %%
ipl.sample(5)
# Out:
#         Unnamed: 0  Match ID        Date  \
# 17018        17018   1082636  2017-05-07
# 140452      140452   1136587  2018-04-28
# 93783        93783    980965  2016-05-05
# 78990        78990    548335  2012-04-22
# 99352        99352    336033  2008-05-24
#
#                                           Venue                    Bat First  \
# 17018                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 140452  Maharashtra Cricket Association Stadium          Chennai Super Kings
# 93783                          Feroz Shah Kotla             Delhi Daredevils
# 78990                          Barabati Stadium              Deccan Chargers
# 99352                    MA Chidambaram Stadium             Rajasthan Royals
#
#                      Bat Second  Innings  Over  Ball       Batter  ...  \
# 17018     Kolkata Knight Riders        2    15     2    YK Pathan  ...
# 140452           Mumbai Indians        1    19     6  SW Billings  ...
# ...

# %%
ipl.to_excel("test.xlsx")
